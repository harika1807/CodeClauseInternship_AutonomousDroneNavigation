# %% [markdown]
# Autonomous Drone Navigation using Deep Q-Learning

# %%
import numpy as np
import cv2
import gym
from collections import deque
import random
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Fix for numpy.bool8 deprecation warning
if not hasattr(np, 'bool8'):
    np.bool8 = np.bool_

# %%
# Step 1: Setup Environment (Using Gym's CartPole as a stand-in for a drone sim)
env = gym.make("CartPole-v1")  # Replace with a drone-specific environment or simulator like AirSim
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
# Step 2: Define the Q-Network
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.out = nn.Linear(64, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

# %%
# Step 3: Create the DQN Agent
class DQNAgent:
    def __init__(self, state_dim, action_dim):
        self.model = QNetwork(state_dim, action_dim)
        self.target = QNetwork(state_dim, action_dim)
        self.memory = deque(maxlen=10000)
        self.optimizer = optim.Adam(self.model.parameters(), lr=1e-3)
        self.batch_size = 64
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, action_dim)
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def remember(self, s, a, r, s2, done):
        self.memory.append((s, a, r, s2, done))

    def learn(self):
        if len(self.memory) < self.batch_size:
            return

        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(states)
        actions = torch.LongTensor(actions).unsqueeze(1)
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        next_states = torch.FloatTensor(next_states)
        dones = torch.FloatTensor(dones).unsqueeze(1)

        q_values = self.model(states).gather(1, actions)
        max_next_q = self.target(next_states).max(1)[0].unsqueeze(1)
        target_q = rewards + self.gamma * max_next_q * (1 - dones)

        loss = nn.MSELoss()(q_values, target_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_target(self):
        self.target.load_state_dict(self.model.state_dict())

# %%
# Step 4: Training Loop
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
agent = DQNAgent(state_dim, action_dim)

episodes = 200
for ep in range(episodes):
    state = env.reset()
    total_reward = 0
    for t in range(500):
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        agent.learn()
        state = next_state
        total_reward += reward
        if done:
            break
    agent.update_target()
    print(f"Episode {ep+1}: Total Reward = {total_reward}")

print("Training complete. Drone agent is ready to navigate!")
# Out:
# Episode 1: Total Reward = 16.0
# Episode 2: Total Reward = 11.0
# Episode 3: Total Reward = 16.0
# Episode 4: Total Reward = 14.0
# Episode 5: Total Reward = 14.0
# <ipython-input-9-ba6070c164d0>:32: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   states = torch.FloatTensor(states)
# Episode 6: Total Reward = 24.0
# Episode 7: Total Reward = 9.0
# Episode 8: Total Reward = 22.0
# Episode 9: Total Reward = 14.0
# Episode 10: Total Reward = 11.0
# Episode 11: Total Reward = 15.0
# Episode 12: Total Reward = 19.0
# Episode 13: Total Reward = 14.0
# Episode 14: Total Reward = 11.0
# Episode 15: Total Reward = 13.0
# Episode 16: Total Reward = 8.0
# Episode 17: Total Reward = 11.0
# Episode 18: Total Reward = 11.0
# Episode 19: Total Reward = 10.0
# Episode 20: Total Reward = 9.0
# Episode 21: Total Reward = 12.0
# Episode 22: Total Reward = 9.0
# Episode 23: Total Reward = 10.0
# Episode 24: Total Reward = 11.0
# Episode 25: Total Reward = 10.0
# Episode 26: Total Reward = 9.0
# Episode 27: Total Reward = 10.0
# Episode 28: Total Reward = 8.0
# Episode 29: Total Reward = 12.0
# Episode 30: Total Reward = 43.0
# Episode 31: Total Reward = 181.0
# Episode 32: Total Reward = 68.0
# Episode 33: Total Reward = 82.0
# Episode 34: Total Reward = 77.0
# Episode 35: Total Reward = 58.0
# Episode 36: Total Reward = 58.0
# Episode 37: Total Reward = 42.0
# Episode 38: Total Reward = 85.0
# Episode 39: Total Reward = 52.0
# Episode 40: Total Reward = 57.0
# Episode 41: Total Reward = 63.0
# Episode 42: Total Reward = 103.0
# Episode 43: Total Reward = 68.0
# Episode 44: Total Reward = 61.0
# Episode 45: Total Reward = 55.0
# Episode 46: Total Reward = 56.0
# Episode 47: Total Reward = 60.0
# Episode 48: Total Reward = 82.0
# Episode 49: Total Reward = 111.0
# Episode 50: Total Reward = 108.0
# Episode 51: Total Reward = 83.0
# Episode 52: Total Reward = 128.0
# Episode 53: Total Reward = 84.0
# Episode 54: Total Reward = 191.0
# Episode 55: Total Reward = 292.0
# Episode 56: Total Reward = 67.0
# Episode 57: Total Reward = 68.0
# Episode 58: Total Reward = 86.0
# Episode 59: Total Reward = 144.0
# Episode 60: Total Reward = 192.0
# Episode 61: Total Reward = 297.0
# Episode 62: Total Reward = 417.0
# Episode 63: Total Reward = 300.0
# Episode 64: Total Reward = 249.0
# Episode 65: Total Reward = 242.0
# Episode 66: Total Reward = 238.0
# Episode 67: Total Reward = 179.0
# Episode 68: Total Reward = 265.0
# Episode 69: Total Reward = 301.0
# Episode 70: Total Reward = 307.0
# Episode 71: Total Reward = 240.0
# Episode 72: Total Reward = 258.0
# Episode 73: Total Reward = 257.0
# Episode 74: Total Reward = 180.0
# Episode 75: Total Reward = 290.0
# Episode 76: Total Reward = 285.0
# Episode 77: Total Reward = 241.0
# Episode 78: Total Reward = 264.0
# Episode 79: Total Reward = 248.0
# Episode 80: Total Reward = 307.0
# Episode 81: Total Reward = 285.0
# Episode 82: Total Reward = 239.0
# Episode 83: Total Reward = 222.0
# Episode 84: Total Reward = 446.0
# Episode 85: Total Reward = 317.0
# Episode 86: Total Reward = 359.0
# Episode 87: Total Reward = 454.0
# Episode 88: Total Reward = 500.0
# Episode 89: Total Reward = 312.0
# Episode 90: Total Reward = 500.0
# Episode 91: Total Reward = 500.0
# Episode 92: Total Reward = 500.0
# Episode 93: Total Reward = 262.0
# Episode 94: Total Reward = 408.0
# Episode 95: Total Reward = 330.0
# Episode 96: Total Reward = 285.0
# Episode 97: Total Reward = 377.0
# Episode 98: Total Reward = 500.0
# Episode 99: Total Reward = 500.0
# Episode 100: Total Reward = 500.0
# Episode 101: Total Reward = 500.0
# Episode 102: Total Reward = 218.0
# Episode 103: Total Reward = 491.0
# Episode 104: Total Reward = 500.0
# Episode 105: Total Reward = 319.0
# Episode 106: Total Reward = 250.0
# Episode 107: Total Reward = 290.0
# Episode 108: Total Reward = 245.0
# Episode 109: Total Reward = 500.0
# Episode 110: Total Reward = 500.0
# Episode 111: Total Reward = 500.0
# Episode 112: Total Reward = 500.0
# Episode 113: Total Reward = 500.0
# Episode 114: Total Reward = 500.0
# Episode 115: Total Reward = 500.0
# Episode 116: Total Reward = 151.0
# Episode 117: Total Reward = 500.0
# Episode 118: Total Reward = 500.0
# Episode 119: Total Reward = 500.0
# Episode 120: Total Reward = 500.0
# Episode 121: Total Reward = 500.0
# Episode 122: Total Reward = 500.0
# Episode 123: Total Reward = 500.0
# Episode 124: Total Reward = 500.0
# Episode 125: Total Reward = 500.0
# Episode 126: Total Reward = 500.0
# Episode 127: Total Reward = 500.0
# Episode 128: Total Reward = 250.0
# Episode 129: Total Reward = 500.0
# Episode 130: Total Reward = 500.0
# Episode 131: Total Reward = 500.0
# Episode 132: Total Reward = 500.0
# Episode 133: Total Reward = 500.0
# Episode 134: Total Reward = 500.0
# Episode 135: Total Reward = 500.0
# Episode 136: Total Reward = 500.0
# Episode 137: Total Reward = 500.0
# Episode 138: Total Reward = 500.0
# Episode 139: Total Reward = 500.0
# Episode 140: Total Reward = 500.0
# Episode 141: Total Reward = 500.0
# Episode 142: Total Reward = 500.0
# Episode 143: Total Reward = 500.0
# Episode 144: Total Reward = 500.0
# Episode 145: Total Reward = 500.0
# Episode 146: Total Reward = 500.0
# Episode 147: Total Reward = 500.0
# Episode 148: Total Reward = 359.0
# Episode 149: Total Reward = 500.0
# Episode 150: Total Reward = 339.0
# Episode 151: Total Reward = 500.0
# Episode 152: Total Reward = 500.0
# Episode 153: Total Reward = 500.0
# Episode 154: Total Reward = 500.0
# Episode 155: Total Reward = 500.0
# Episode 156: Total Reward = 500.0
# Episode 157: Total Reward = 500.0
# Episode 158: Total Reward = 398.0
# Episode 159: Total Reward = 408.0
# Episode 160: Total Reward = 500.0
# Episode 161: Total Reward = 500.0
# Episode 162: Total Reward = 500.0
# Episode 163: Total Reward = 500.0
# Episode 164: Total Reward = 443.0
# Episode 165: Total Reward = 500.0
# Episode 166: Total Reward = 500.0
# Episode 167: Total Reward = 500.0
# Episode 168: Total Reward = 500.0
# Episode 169: Total Reward = 500.0
# Episode 170: Total Reward = 500.0
# Episode 171: Total Reward = 500.0
# Episode 172: Total Reward = 500.0
# Episode 173: Total Reward = 500.0
# Episode 174: Total Reward = 500.0
# Episode 175: Total Reward = 500.0
# Episode 176: Total Reward = 500.0
# Episode 177: Total Reward = 500.0
# Episode 178: Total Reward = 500.0
# Episode 179: Total Reward = 500.0
# Episode 180: Total Reward = 500.0
# Episode 181: Total Reward = 500.0
# Episode 182: Total Reward = 500.0
# Episode 183: Total Reward = 407.0
# Episode 184: Total Reward = 321.0
# Episode 185: Total Reward = 340.0
# Episode 186: Total Reward = 432.0
# Episode 187: Total Reward = 500.0
# Episode 188: Total Reward = 500.0
# Episode 189: Total Reward = 500.0
# Episode 190: Total Reward = 500.0
# Episode 191: Total Reward = 500.0
# Episode 192: Total Reward = 333.0
# Episode 193: Total Reward = 411.0
# Episode 194: Total Reward = 500.0
# Episode 195: Total Reward = 500.0
# Episode 196: Total Reward = 500.0
# Episode 197: Total Reward = 500.0
# Episode 198: Total Reward = 500.0
# Episode 199: Total Reward = 500.0
# Episode 200: Total Reward = 500.0
# Training complete. Drone agent is ready to navigate!
